# %% [markdown]
# # MatPlotlib를 활용한 시각화

# %% [markdown]
# Matplotlib는 다중 플랫폼 데이터 시각화 라이브러리이다. 다양한 운영체제에서 동작할 수 있는 점이 가장 큰 장점으로 파이썬에서도 활용할 수 있다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
# 모듈처럼 한 번만 실행

# %%
import numpy as np

# %% [markdown]
# ### 기본 예제

# %%
x = np.linspace(0, 1, 2)

# %%
x = np.array([0,1])

# %%
fig = plt.figure()
plt.plot(x, x+1, '-')
#plt.plot(x, np.cos(x), '--')

# %% [markdown]
# ### 그림을 파일로 저장하기

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# ### (jupyter notebook에서) 그림파일 읽어오기

# %%
from IPython.display import Image

# %%
Image('./my_figure.png')

# %% [markdown]
# ### 두가지 인터페이스

# %% [markdown]
# Matplotlib는 매트랩 스타일의 인터페이스와 객체지향 인터페이스 2가지를 지원한다.

# %% [markdown]
# #### 매트랩 인터페이스

# %%
plt.figure() # 플롯 그림 생성

# 두개의 패널 중 첫 패널을 생성

plt.subplot(2, 1, 1) #(rows, columns, panel number)
plt.plot(x, np.sin(x))

# %%
# 두번째 패널 생성
plt.subplot(2, 1, 2) #(rows, columns, panel number)
plt.plot(x, np.cos(x))

# %% [markdown]
# #### 객체지향 인터페이스

# %%
# 전체 플롯그리드(fig), 두 객체의 배열(ax) 생성
fig, ax = plt.subplots(2)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# ## 간단한 라인 플롯

# %% [markdown]
# 모든 Matplotlib 플롯은 그림(figure)와 축(axes)를 만드는 것으로 시작
# - 그림(figure) : 축, 그래픽, 텍스트, 레이블을 표시하는 하나의 컨테이너(ex) 그림이 그려지는 종이)
# - 축(axes) : 하나의 플롯 그래프( 영어에서 축을 의미하는 axis의 복수가 axes, 철자에 주의하자)
# - axis : x축, y축을 의미

# %%
plt.style.use('seaborn-whitegrid')

fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x))

# %% [markdown]
# ### 플롯 수정하기 : 선 색상과 스타일

# %% [markdown]
# 플롯에서 선의 색상과 스타일을 수정할 때 plt.plot() 함수의 color 키워드를 사용

# %%
plt.plot(x, np.sin(x-0), color='blue')
plt.plot(x, np.sin(x-1), color='g')
plt.plot(x, np.sin(x-2), color='0.75')
plt.plot(x, np.sin(x-3), color='#FFDD44')
plt.plot(x, np.sin(x-4), color=(0,1,0))

# %% [markdown]
# linestyle 키워드를 활용하면 선 스타일을 선택할 수 있다.

# %%
plt.plot(x, x+0, linestyle='solid')
plt.plot(x, x+1, linestyle='dashed')
plt.plot(x, x+2, linestyle='dashdot')
plt.plot(x, x+3, linestyle='dotted')

plt.plot(x, x+4, linestyle='-')
plt.plot(x, x+5, linestyle='--')
plt.plot(x, x+6, linestyle='-.')
plt.plot(x, x+7, linestyle=':')

# %% [markdown]
# linestyle과 color코드를 합쳐 표현할 수도 있다.

# %%
plt.plot(x, x+0, '-g')  # solid + green
plt.plot(x, x+1, '--c') # dashed + cyan
plt.plot(x, x+2, '-.k') # dashdot + black
plt.plot(x, x+3, ':r')  # dotted + red

# %% [markdown]
# 단일문자로 표현되는 색상은 RGB(Red, Green, Blue), CMYK(Cyan(청록), Magenta(자홍), Yellow, BlacK)의 약어이다.

# %% [markdown]
# ### 플롯 조정하기 : 축 경계

# %% [markdown]
# Matplotlib은 기본적으로 축 경계를 자동으로 설정한다. 축 경계를 조정하기 위해서는 plt.xlim(), plt.ylim() 매서드를 활용한다.

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# 축을 반대로 표시해야 하면 인수의 순서를 바꾸자

# %%
plt.plot(x, np.sin(x))
plt.xlim(10,0)
plt.ylim(1.2,-1.2)
# Out:
# (1.2, -1.2)

# %% [markdown]
# plt.axis() 매서드는 [x축 최소값, x축 최대값, y축 최소값, y축 최대값]를 지정하는 리스트로 x, y축을 설정한다.

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5,1.5])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# 축에 대한 리스트 값 대신 plt.axis()의 매개변수로
# - 'tight'를 주면 플롯 주변의 경계를 밀착시킬 수 있고,
# - 'equal'을 지정하면 축의 단위를 똑같게 설정하여 보여준다.

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %% [markdown]
# ### 플롯에 레이블 붙이기

# %% [markdown]
# 플롯에 제목, 축 레이블(축이름), 간단한 범례를 추가할 수 있다.

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve", fontsize=20, color='green', loc='center')
plt.xlabel("X")
plt.ylabel("sin(X)")
# Out:
# Text(0, 0.5, 'sin(X)')

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve", fontsize=20, color='green', loc='center')
plt.xlabel("X", fontsize=15, color='blue')
plt.ylabel("sin(X)", fontsize=15, color='red')
# Out:
# Text(0, 0.5, 'sin(X)')

# %% [markdown]
# 범례를 만들려면 1) label 키워드를 사용해 각 라인의 레이블을 지정하고, 2) plt.legend() 메서드를 사용한다.

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), '-b', label='cos(x)')
plt.axis('equal')

plt.legend()

# %%
x = np.linspace(-2, 2, 10000)
y = lambda x: (np.sqrt(np.cos(x)) * np.cos(200 * x) + np.sqrt(abs(x)) - 0.7) * pow((4 - x * x), 0.01)
    
plt.plot(x, list(map(y,x)))
# Out:
# /Users/raejin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %% [markdown]
# ##### Quiz
# 다음 데이터로 그래프를 그리세요.

# %%
x = [2011, 2012, 2013, 2014, 2015, 2016, 2017]
y = [3.68, 2.29, 2.90, 3.34, 2.79, 2.83, 3.10]
plt.plot(x, y, linestyle="solid", color="blue")
plt.ylim(2.0,4.0)
plt.title("Economic growth rate")
plt.xlabel("year")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %% [markdown]
# ## 산점도(Scatter plot)

# %% [markdown]
# 산점도는 점을 선으로 연결하는 대신 데이터를 개별적인 원 혹은 다른 기호로 표현한다

# %% [markdown]
# ### plt.plot을 사용한 산점도

# %%
x = np.linspace(0,10,30)

# %%
y = np.sin(x)

# %%
# https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(x,y,'^', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o','.',',','x','v','^','<','>','s','d']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker=%s" % marker)
    plt.legend(numpoints=1) # numpoints 키워드는 범례의 마커 표시 갯 수
    plt.xlim(0, 1.8)

# %%
plt.plot(x, y, '-.^y') # 선 마커기호 노랑

# %%
x = np.linspace(0,10,30)
y = np.sin(x)
plt.plot(x, y, '-p', color='gray',
        markersize = 15, 
        linewidth = 4,
        markerfacecolor = 'white',
        markeredgecolor = 'gray',
        markeredgewidth = 2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ### plt.scatter를 활용한 산점도

# %% [markdown]
# plt.plot 함수와 비슷하게 사용할 수 있는 plt.scatter 함수가 있다.

# %%
plt.scatter(x,y,marker='o')

# %% [markdown]
# plt.scatter는 plt.plot와 달리 각 점의 속성(크기, 표면 색상, 테두리, 색상 등)을 개별적으로 제어하거나 데이터에 매핑할 수 있다.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100) # 평균이 0이고 표준편차가 1인 정규분포 값 100개
colors = rng.rand(100) # 0 ~ 1 사이 값 100개
sizes = 1000 * rng.rand(100)

plt.scatter(x,y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar()

# %%
import pandas as pd
iris = pd.read_csv('iris.csv')

# %%
iris.head()
# Out:
#    caseno  SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0       1          5.1         3.5          1.4         0.2  setosa
# 1       2          4.9         3.0          1.4         0.2  setosa
# 2       3          4.7         3.2          1.3         0.2  setosa
# 3       4          4.6         3.1          1.5         0.2  setosa
# 4       5          5.0         3.6          1.4         0.2  setosa

# %%
def setColor(x):
    if x == 'setosa':
        return 0
    elif x == 'versicolor':
        return 1
    elif x == 'virginica':
        return 2
    else:
        return np.nan

# %%
iris['color'] = list(map(setColor,iris['Species']))

# %%
iris.head()
# Out:
#    caseno  SepalLength  SepalWidth  PetalLength  PetalWidth Species  color
# 0       1          5.1         3.5          1.4         0.2  setosa      0
# 1       2          4.9         3.0          1.4         0.2  setosa      0
# 2       3          4.7         3.2          1.3         0.2  setosa      0
# 3       4          4.6         3.1          1.5         0.2  setosa      0
# 4       5          5.0         3.6          1.4         0.2  setosa      0

# %%
plt.scatter(iris['SepalLength'], iris['SepalWidth'], alpha=0.2, 
           s = 100 * iris['PetalWidth'], c = iris['color'], cmap='autumn')

# %%
import pandas as pd
app = pd.read_csv('apple_store 2.csv')
app.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %% [markdown]
# ##### Quiz) 모바일 앱의 가격 대비 평점을 산점도로 표기하고 점의 크기로 지원하는 언어의 갯 수를 3부분(상(2)중(1),하(0))로 나누어 표현해주세요

# %%
v = pd.qcut(app['lang.num'], 3, labels=['0','1','2']).astype(int)

plt.scatter(app['user_rating'], app['price'], alpha=0.2, 
           s = (app['lang.num']*50), c = v, cmap='autumn')

plt.ylim(0,15)
# Out:
# (0, 15)

# %% [markdown]
# ## 오차 시각화하기

# %% [markdown]
# ### 오차 막대

# %% [markdown]
# 데이터의 결과의 시각화에서 오차를 효과적으로 보여주면 훨씬 더 완전한 정보를 전달 할 수 있다.
# - 예시) 설문조사 오차, 천체물리 관측치

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# fmt은 선과 점의 모양을 제어하는 키워드로 라인과 산점도에서 활용했던 스타일과 색상의 약칭을 입력한다.

# %%
plt.errorbar(x, y, xerr=dy, fmt='o', color='k', 
             ecolor='lightgray', elinewidth=3, capsize=5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ecolor는 오류부분의 색상,
# elinewidth는 오류 부분의 너비
# capsize는 오류 경계부분의 사이즈

# %% [markdown]
# ##### quiz
# 다음 데이터를 활용하여 분기별 지지도(%)를 오차막대로 표시하세요.
#
# - 데이터)
#     - time = ['1Quarter','2Quarter','3Quarter','4Quarter']
#     - clinton = [51, 49, 44, 42]
#     - trump = [34, 38, 47, 45]
# - 오차)
#     - -2 ~ 2 %

# %%
time = ['1Quarter','2Quarter','3Quarter','4Quarter']
clinton = [51, 49, 44, 42]
trump = [34, 38, 47, 45]
dy = 2

plt.errorbar(time, clinton, 
             yerr = dy, color='blue', ecolor='lightblue', 
             elinewidth=5, capsize=10)
plt.errorbar(time, trump,
             yerr = dy, color='red', ecolor='lightcoral',
             elinewidth=5, capsize=10)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## 밀도 플롯과 등고선 플롯

# %% [markdown]
# 3차원 데이터를 등고선이나 색으로 구분한 영역을 사용해 2차원으로 표시하는 것이 유용하다. matplotlib은 이를 위한 3가지 함수(plt.contour, plot.contourf)를 지원한다

# %% [markdown]
# ### 3차원 함수 시각화 하기

# %% [markdown]
# 다음 함수로 등고선 플롯을 그려보자

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10+y*x) * np.cos(x)

# %%
x = np.linspace(0,4,3)
y = np.linspace(0,4,3)
X,Y = np.meshgrid(x,y) # 가로축 세로축을 이루는 점 좌표를 받아 사각형 영역을 이루는 조합 출력

# %%
plt.scatter(X, Y, linewidths=10)

# %%
x = np.linspace(0,5,50)
y = np.linspace(0,5,40)
X,Y = np.meshgrid(x,y) 

Z = f(X, Y)

# %% [markdown]
# plot.contour함수로 등고선 플롯을 만들어 보자

# %%
plt.contour(X, Y, Z, colors='Black') # x, y는 플롯의 위치 z는 등고선의 높이를 의미

# %% [markdown]
# x,y,z, 다음에 간격수 20을 입력하여 데이터의 범위를 나누었다.
# cmap 인수로 색상표를 지정해 선에 색을 입힐 수 있다.

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')

# %% [markdown]
# 색상표는 plt.cm 모듈에 정의 되어 있으므로 탭 완성 기능을 이용하여 색상을 쉽게 확인 가능하다.

# %% [markdown]
# plt.cm.Tab키

# %% [markdown]
# plt.contourf()함수는 선 사이의 공간안에 색을 체워 등고선 플롯을 그릴 수 있다.

# %%
plt.contourf(X,Y,Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# plt.imshow()함수는 2차원 데이터 그리드를 이미지로 해석하여 부드러운 형태의 플롯을 그릴 수 있다.
# 다만
# - plt.imshop()은 x, y 그리드 좌표를 받지 않으므로 플롯의 이미지 크기 extent를 직접 지정한다.
#     - [x_min,x_max,y_min,y_max]

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image')
# Out:
# (0.0, 5.0, 0.0, 5.0)

# %% [markdown]
# ## 히스토그램, 구간화, 밀도

# %% [markdown]
# 데이터세트의 데이터 분포를 알아보기 히스토그램이 많이 활용된다.

# %%
data = np.random.randn(1000) # 평균 0 편차가 1인 정규분포

# %%
plt.hist(data)
# Out:
# (array([  3.,  24.,  65., 143., 231., 233., 178.,  82.,  26.,  15.]),
#  array([-3.23852645, -2.61863316, -1.99873987, -1.37884658, -0.75895329,
#         -0.13906   ,  0.48083329,  1.10072658,  1.72061987,  2.34051317,
#          2.96040646]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# hist() 함수의 옵션들을 통해 그래프 표현을 조정할 수 있다.
# - bins : 막대의 수
# - alpha : 막대 색상의 투명도
# - color : 막대 색상
# - edgecolor : 막대의 테두리 색
# - rwidth : 막대간 간격

# %%
plt.hist(data, bins=5, alpha = 0.5, edgecolor='red', rwidth=0.9)
# Out:
# (array([ 27., 208., 464., 260.,  41.]),
#  array([-3.23852645, -1.99873987, -0.75895329,  0.48083329,  1.72061987,
#          2.96040646]),
#  <a list of 5 Patch objects>)

# %%
x1 = np.random.normal(0,0.8,1000) #평균 0, 표준편차 0.8인 숫자 1000개
x2 = np.random.normal(-2,1,1000)

# %%
x3 = np.random.normal(3, 2, 1000)

# %%
plt.hist(x1, bins=40, alpha = 0.3)
plt.hist(x2, bins=40, alpha = 0.3)
plt.hist(x3, bins=40, alpha = 0.3)
# Out:
# (array([ 1.,  0.,  2.,  0.,  2.,  2.,  7.,  3.,  6.,  9., 16., 18., 17.,
#         29., 34., 38., 49., 54., 56., 57., 63., 66., 67., 50., 48., 59.,
#         47., 44., 29., 34., 24., 20., 14., 14.,  5.,  5.,  1.,  6.,  3.,
#          1.]),
#  array([-3.6832301 , -3.36832293, -3.05341575, -2.73850858, -2.42360141,
#         -2.10869423, -1.79378706, -1.47887988, -1.16397271, -0.84906554,
#         -0.53415836, -0.21925119,  0.09565599,  0.41056316,  0.72547034,
#          1.04037751,  1.35528468,  1.67019186,  1.98509903,  2.30000621,
#          2.61491338,  2.92982055,  3.24472773,  3.5596349 ,  3.87454208,
#          4.18944925,  4.50435642,  4.8192636 ,  5.13417077,  5.44907795,
#          5.76398512,  6.0788923 ,  6.39379947,  6.70870664,  7.02361382,
#          7.33852099,  7.65342817,  7.96833534,  8.28324251,  8.59814969,
#          8.91305686]),
#  <a list of 40 Patch objects>)

# %%
argu = dict(bins=4, alpha = 0.3)

plt.hist(x1, **argu)
#plt.hist(x2, **argu)
#plt.hist(x3, **argu)
# Out:
# (array([ 34., 368., 527.,  71.]),
#  array([-2.83663363, -1.5021199 , -0.16760617,  1.16690756,  2.50142128]),
#  <a list of 4 Patch objects>)

# %% [markdown]
# 히스토그램 계산만 하고 표시만 한다면(구간에 해당하는 갯수만 샐 때) np.histogram() 함수를 활용

# %%
counts, bin_edges = np.histogram(x1, bins=4)

# %%
counts
# Out:
# array([ 34, 368, 527,  71])

# %%
bin_edges
# Out:
# array([-2.83663363, -1.5021199 , -0.16760617,  1.16690756,  2.50142128])

# %% [markdown]
# ### 2차원 히스토그램과 구간화

# %% [markdown]
# 숫자 선을 구간(bin)으로 나누어 1차원 히스토그램을 만드는 것처럼 2차원 구간에 나누어 히스토그램을 만들 수 있다.

# %%
x = np.random.randn(1000000)
y = np.random.randn(1000000)
plt.hist2d(x,y, bins=100, cmap='Blues')
plt.colorbar()

# %% [markdown]
# ##### Quiz)
# 앞의 퀴즈에서 진행한 모바일 앱 데이터프레임에서 앱의 카테고리마다 구분하여 갯수를 표시하는 히스토그램을 그리자

# %%
import pandas as pd

app = pd.read_csv('apple_store 2.csv')
app.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# 0          4.0              4.5   6.3.5          4+         Games
# 1          4.0              3.5   8.2.2          4+  Productivity
# 2          3.5              4.5   5.0.0          4+       Weather
# 3          4.0              4.5  5.10.0         12+      Shopping
# 4          4.5              5.0   7.5.1          4+     Reference
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1
# 3               37                5         9        1
# 4               37                5        45        1

# %% [markdown]
# 참고)

# %%
len(app.groupby('prime_genre')['prime_genre']) # 카태고리 갯수는 21개
# Out:
# 21

# %% [markdown]
# - plt.figure(figsize=(12, 3)) # 플롯의 사이즈를 수정하는 figsize(너비, 높이) 키워드
# - plt.xticks(rotation=90) # x축의 눈금값을 90도로 회전하는 rotation 키워드

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

app = pd.read_csv('apple_store 2.csv')
app.head()

plt.style.use('seaborn-white')
plt.figure(figsize=(20, 3))
data= app['prime_genre']
data.unique()
match = { '':0,'Games':1, 'Productivity':2, 'Weather':3, 'Shopping':4, 'Reference':5,
       'Finance':6, 'Music':7, 'Utilities':8, 'Travel':9, 'Social Networking':10,
       'Sports':11, 'Business':12, 'Health & Fitness':13, 'Entertainment':14,
       'Photo & Video':15, 'Navigation':16, 'Education':17, 'Lifestyle':18,
       'Food & Drink':19, 'News':20, 'Book':21 }
data2 = app['prime_genre'].apply(lambda x:match[x])
data2
labels = match.keys()
n = len(match)
pos = range(n)
plt.hist(data2, bins=21, alpha = 0.3)
plt.xticks(pos, labels, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x1327b5fd0>,
#   <matplotlib.axis.XTick at 0x1327b5860>,
#   <matplotlib.axis.XTick at 0x1327b5588>,
#   <matplotlib.axis.XTick at 0x1326b04a8>,
#   <matplotlib.axis.XTick at 0x1326b0940>,
#   <matplotlib.axis.XTick at 0x1326b0e48>,
#   <matplotlib.axis.XTick at 0x1326aa400>,
#   <matplotlib.axis.XTick at 0x1326aa978>,
#   <matplotlib.axis.XTick at 0x1326aaef0>,
#   <matplotlib.axis.XTick at 0x1326b0a20>,
#   <matplotlib.axis.XTick at 0x132767be0>,
#   <matplotlib.axis.XTick at 0x1327675f8>,
#   <matplotlib.axis.XTick at 0x132767160>,
#   <matplotlib.axis.XTick at 0x13275ab70>,
#   <matplotlib.axis.XTick at 0x13275a588>,
#   <matplotlib.axis.XTick at 0x13275a198>,
#   <matplotlib.axis.XTick at 0x1327594e0>,
#   <matplotlib.axis.XTick at 0x132759a58>,
#   <matplotlib.axis.XTick at 0x13275aa20>,
#   <matplotlib.axis.XTick at 0x1326b0dd8>,
#   <matplotlib.axis.XTick at 0x132759ef0>,
#   <matplotlib.axis.XTick at 0x1327534a8>],
#  <a list of 22 Text xticklabel objects>)

# %% [markdown]
# ## 플롯 범례 변경하기

# %% [markdown]
# Matplotlib에서 범례의 모양과 위치를 맞춤 변경하는 것을 알아보자

# %%
plt.style.use('classic')
x = np.linspace(0,10,1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sin')
ax.plot(x, np.cos(x), '--r', label='Cos')
ax.axis('equal')
leg = ax.legend()

# %% [markdown]
# legend()함수의 loc 키워드로 범례의 위치를 frameon 키워드로 테두리를 지정할 수 있다.

# %%
ax.legend(loc='lower left', frameon=False) # upper/lower left/right/center
fig

# %% [markdown]
# 이외에 둥근 모서리박스 사용(fancybox), 투명도(framealpha), 음영(shadow), 박스내 여백(borderpad) 등을 변경할 수 있다.

# %%
ax.legend(fancybox=True, framealpha=0.5, shadow=True, borderpad=1)
fig

# %% [markdown]
# ### 점 크기에 대한 범례

# %%
cities = pd.read_csv('./california_cities.csv')

# %%
cities.head()

# %%
lat, lon = cities['latd'], cities['longd']

# %%
population, area = cities['population_total'], cities['area_total_km2']

# %%
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=area, linewidth=0, alpha=0.5)

plt.colorbar(label='log$_{10}$(population)') # $_{아래첨자}$


for area2 in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area2,
                label=str(area2) + ' km$^2$') # $^윗첨자$
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')


plt.title('California Cities: Area and Population');

# %% [markdown]
# 범례는 항상 플롯상의 객체를 참조하므로 특정 모양을 포시하려면 플로팅해야한다. 회색원은 플롯상에 없으므로 빈 리스트를 가지고 임시의 객체를 만들어 표시한다.

# %% [markdown]
# ## 서브 플롯

# %% [markdown]
# 자료를 비교할 때 서로 다른 데이터 뷰를 나란히 비교하는 것이 유용하다. Matplotlib에서는 서브플롯(subplot)이라는 개념이 있다.

# %% [markdown]
# ### 그리드 형태

# %% [markdown]
# plt.subplot(격자의 행, 격자의 열, 서브플롯의 인덱스)함수는 그리드(격자)안에 들어갈 여러 서브플롯을 생성한다.

# %%
for i in range(1,7):
    plt.subplot(2,3,i)
    plt.text(0.5, 0.5, str((2,3,i)),fontsize=18, ha='center')

# %% [markdown]
# plt.subplots_adjust()함수의 hspace, wspace로 플롯 간 높이, 너비 사이의 간격을 조정할 수 있다

# %%
plt.subplots_adjust(hspace=0.5, wspace=0.3)
for i in range(1,7):
    plt.subplot(2,3,i)
    plt.text(0.5, 0.5, str((2,3,i)),fontsize=18, ha='center')
