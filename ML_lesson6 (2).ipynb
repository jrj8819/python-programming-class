# %% [markdown]
# ### 데이터셋 결합하기 : 병합과 조인

# %% [markdown]
# Pandas는 pd.merge() 함수를 활용하여 고성능 인메모리 조인과 병합연산을 할 수 있다

# %% [markdown]
# #### 조인 작업의 분류

# %% [markdown]
# pd.merge() 함수는 일대일, 다대일, 다대다 같은 여러가지 조인 유형을 구현한다.

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame({'employee':['Bob', 'Jake','Lisa','Sue'],
                   'group': ['Accounting', 'Engineering', 
                             'Engineering', 'HR']})

# %%
df2 = pd.DataFrame({'employee' : ['Lisa','Bob','Jake','Sue'], 
                    'hire_date': [2004, 2000, 2012, 2014]})

# %%
print(df1) ; print(df2)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2000
# 2     Jake       2012
# 3      Sue       2014

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2000
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %% [markdown]
# ### 다대일(Many-to-one) 조인

# %% [markdown]
# 병합하는 키 열 하나에 중복된 항목이 포함되는 경우의 조인

# %%
df4 = pd.DataFrame({'group':['Accounting','Engineering', 'HR'],
                             'supervisor':['Carly', 'Guido','Steve']})

# %%
print(df4) ; print(df3)
# Out:
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve
#   employee        group  hire_date
# 0      Bob   Accounting       2000
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
pd.merge(df3, df4)
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2000      Carly
# 1     Jake  Engineering       2012      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2014      Steve

# %%
### 다대다(Many-to-many) 조인

# %% [markdown]
# 병합되는 두 데이터프레임에서 키열에 대해 모두 중복항목이 존재하면 다대다 조인이다.

# %%
df5 = pd.DataFrame({'group':
                    ['Accounting','Accounting',
                     'Engineering','Engineering','HR','HR'],
                   'skills':
                    ['math','spreadsheets','coding',
                     'linux','spreadsheets','organiation']})

# %%
print(df1) ; print(df5)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR  spreadsheets
# 5           HR   organiation

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR  spreadsheets
# 7      Sue           HR   organiation

# %% [markdown]
# #### 병합 키 지정

# %% [markdown]
# pd.merge()는 두개의 입력 데이터셋 사이에 일치하는 하나 이상의 열 이름을 찾아 그것을 키로 사용한다.

# %% [markdown]
# #### on 키워드

# %% [markdown]
# on 키워드를 사용해 키로 쓸 열이름을 명시적으로 지정할 수 있다.

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2000
# 2     Jake       2012
# 3      Sue       2014

# %%
pd.merge(df1, df2, on='employee')
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2000
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %% [markdown]
# #### left_on과 right_on 키워드

# %% [markdown]
# 다른 열이름을 가진 두 데이터셋을 병합하려면, left_on과 right_on 키워드를 활용한다

# %%
df3 = pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],
                   'salary':[70000,80000,120000,90000]})

# %%
print(df1); print(df3)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#    name  salary
# 0   Bob   70000
# 1  Jake   80000
# 2  Lisa  120000
# 3   Sue   90000

# %%
pd.merge(df1, df3, left_on="employee", right_on="name")
# Out:
#   employee        group  name  salary
# 0      Bob   Accounting   Bob   70000
# 1     Jake  Engineering  Jake   80000
# 2     Lisa  Engineering  Lisa  120000
# 3      Sue           HR   Sue   90000

# %%
pd.merge(df1, df3, left_on="employee", right_on="name").drop('name', axis=1)
# Out:
#   employee        group  salary
# 0      Bob   Accounting   70000
# 1     Jake  Engineering   80000
# 2     Lisa  Engineering  120000
# 3      Sue           HR   90000

# %% [markdown]
# ### left_index와 right_index 키워드 그리고 join() 메서드

# %% [markdown]
# 기본적으론 열을 기준으로 병합하지만 left_index, right_index를 활용하면 인덱스로 병합할 수 있다.

# %%
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df1a = df1.set_index('employee')

# %%
df1a
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR

# %%
df2a = df2.set_index('employee')

# %%
df2a
# Out:
#           hire_date
# employee
# Lisa           2004
# Bob            2000
# Jake           2012
# Sue            2014

# %%
pd.merge(df1a, df2a, left_index=True, right_index=True)
# Out:
#                 group  hire_date
# employee
# Bob        Accounting       2000
# Jake      Engineering       2012
# Lisa      Engineering       2004
# Sue                HR       2014

# %%
pd.merge(df1a, df2a, left_index=True, right_index=True).reset_index()
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2000
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
df1a.join(df2a)
# Out:
#                 group  hire_date
# employee
# Bob        Accounting       2000
# Jake      Engineering       2012
# Lisa      Engineering       2004
# Sue                HR       2014

# %% [markdown]
# ### 인덱스와 열

# %% [markdown]
# 두 데이터셋에서 하나는 인덱스로 다른 것은 열로 섞고자 하면 left_index와 right_on, left_on과 right_index를 조합할 수 있다.

# %%
print(df1a) ; print(df3)
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR
#    name  salary
# 0   Bob   70000
# 1  Jake   80000
# 2  Lisa  120000
# 3   Sue   90000

# %%
pd.merge(df1a, df3, left_index=True, right_on='name')
# Out:
#          group  name  salary
# 0   Accounting   Bob   70000
# 1  Engineering  Jake   80000
# 2  Engineering  Lisa  120000
# 3           HR   Sue   90000

# %%
print(df1) ; print(df1a)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR

# %% [markdown]
# ##### Quiz) 두 개(df1, df1a)의 데이터 프레임을 병합해 주세요

# %%
pd.merge(df1, df1a, left_on='employee', right_index=True)
# Out:
#   employee      group_x      group_y
# 0      Bob   Accounting   Accounting
# 1     Jake  Engineering  Engineering
# 2     Lisa  Engineering  Engineering
# 3      Sue           HR           HR

# %% [markdown]
# ### 조인을 위한 집합연산 지정하기

# %% [markdown]
# 데이터셋에 따라 키열에 맞는 값이 등장하거나 등장하지 않는 경우가 있다.

# %%
df6 = pd.DataFrame({'name':['Peter','Paul','Mary'],
                   'food':['fish','beans','bread']},
                  columns=['name','food'])

# %%
df7 = pd.DataFrame({'name':['Mary','Joseph'],
                   'drink':['wine','beer']},
                  columns=['name','drink'])

# %%
pd.merge(df6, df7)
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %% [markdown]
# 결과가 두 데이터 집합에 대한 교집합이 들어간다. 이를 내부조인(inner join)이라 한다. how 키워드를 활용하여 outer, left, right로 기준을 정할 수 있다.

# %%
pd.merge(df6, df7, how='outer')
# Out:
#      name   food drink
# 0   Peter   fish   NaN
# 1    Paul  beans   NaN
# 2    Mary  bread  wine
# 3  Joseph    NaN  beer

# %%
pd.merge(df6, df7, how='left')
# Out:
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine

# %%
print(df6) ; print(df7)
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
#      name drink
# 0    Mary  wine
# 1  Joseph  beer

# %%
pd.merge(df6, df7, how='right')
# Out:
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  beer

# %% [markdown]
# #### 열 이름이 겹치는 경우 : suffixes 키워드

# %% [markdown]
# 두 데이터 셋에서 열이름이 충돌하는 경우 자동으로 접미사 _x, _y가 붙는다.

# %%
df8 = pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],'rank':[1,2,3,4]})

# %%
df9 = pd.DataFrame({'name':['Bob','Jake','Lisa','Sue'],'rank':[3,1,4,2]})

# %%
df8
# Out:
#    name  rank
# 0   Bob     1
# 1  Jake     2
# 2  Lisa     3
# 3   Sue     4

# %%
df9
# Out:
#    name  rank
# 0   Bob     3
# 1  Jake     1
# 2  Lisa     4
# 3   Sue     2

# %%
pd.merge(df8, df9, on='name')
# Out:
#    name  rank_x  rank_y
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %% [markdown]
# 기본값이 싫다면 suffixes 키워드를 사용해 별도로 지정할 수 있다.

# %%
pd.merge(df8, df9, on="name", 
         suffixes=["_left","_right"])
# Out:
#    name  rank_left  rank_right
# 0   Bob          1           3
# 1  Jake          2           1
# 2  Lisa          3           4
# 3   Sue          4           2

# %% [markdown]
# ##### Quiz
# 두개의 데이터 셋(state-abbresv.csv, state-population.csv)을 외부조인 하여 병합하세요

# %%
pop = pd.read_csv('state-population.csv')
abbrevs = pd.read_csv('state-abbrevs.csv')

abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
pd.merge(abbrevs, pop, left_on='abbreviation', 
         right_on='state/region', how='outer').drop('state/region',
                                                   axis=1)
# Out:
#         state abbreviation     ages  year   population
# 0     Alabama           AL  under18  2012    1117489.0
# 1     Alabama           AL    total  2012    4817528.0
# 2     Alabama           AL  under18  2010    1130966.0
# 3     Alabama           AL    total  2010    4785570.0
# 4     Alabama           AL  under18  2011    1125763.0
# 5     Alabama           AL    total  2011    4801627.0
# 6     Alabama           AL    total  2009    4757938.0
# 7     Alabama           AL  under18  2009    1134192.0
# 8     Alabama           AL  under18  2013    1111481.0
# 9     Alabama           AL    total  2013    4833722.0
# 10    Alabama           AL    total  2007    4672840.0
# 11    Alabama           AL  under18  2007    1132296.0
# 12    Alabama           AL    total  2008    4718206.0
# 13    Alabama           AL  under18  2008    1134927.0
# 14    Alabama           AL    total  2005    4569805.0
# 15    Alabama           AL  under18  2005    1117229.0
# 16    Alabama           AL    total  2006    4628981.0
# 17    Alabama           AL  under18  2006    1126798.0
# 18    Alabama           AL    total  2004    4530729.0
# 19    Alabama           AL  under18  2004    1113662.0
# 20    Alabama           AL    total  2003    4503491.0
# 21    Alabama           AL  under18  2003    1113083.0
# 22    Alabama           AL    total  2001    4467634.0
# 23    Alabama           AL  under18  2001    1120409.0
# 24    Alabama           AL    total  2002    4480089.0
# 25    Alabama           AL  under18  2002    1116590.0
# 26    Alabama           AL  under18  1999    1121287.0
# 27    Alabama           AL    total  1999    4430141.0
# 28    Alabama           AL    total  2000    4452173.0
# 29    Alabama           AL  under18  2000    1122273.0
# ...       ...          ...      ...   ...          ...
# 2514      NaN          NaN  under18  1999   71946051.0
# 2515      NaN          NaN    total  2000  282162411.0
# 2516      NaN          NaN  under18  2000   72376189.0
# 2517      NaN          NaN    total  1999  279040181.0
# 2518      NaN          NaN    total  2001  284968955.0
# 2519      NaN          NaN  under18  2001   72671175.0
# 2520      NaN          NaN    total  2002  287625193.0
# 2521      NaN          NaN  under18  2002   72936457.0
# 2522      NaN          NaN    total  2003  290107933.0
# 2523      NaN          NaN  under18  2003   73100758.0
# 2524      NaN          NaN    total  2004  292805298.0
# 2525      NaN          NaN  under18  2004   73297735.0
# 2526      NaN          NaN    total  2005  295516599.0
# 2527      NaN          NaN  under18  2005   73523669.0
# 2528      NaN          NaN    total  2006  298379912.0
# 2529      NaN          NaN  under18  2006   73757714.0
# 2530      NaN          NaN    total  2007  301231207.0
# 2531      NaN          NaN  under18  2007   74019405.0
# 2532      NaN          NaN    total  2008  304093966.0
# 2533      NaN          NaN  under18  2008   74104602.0
# 2534      NaN          NaN  under18  2013   73585872.0
# 2535      NaN          NaN    total  2013  316128839.0
# 2536      NaN          NaN    total  2009  306771529.0
# 2537      NaN          NaN  under18  2009   74134167.0
# 2538      NaN          NaN  under18  2010   74119556.0
# 2539      NaN          NaN    total  2010  309326295.0
# 2540      NaN          NaN  under18  2011   73902222.0
# 2541      NaN          NaN    total  2011  311582564.0
# 2542      NaN          NaN  under18  2012   73708179.0
# 2543      NaN          NaN    total  2012  313873685.0
#
# [2544 rows x 5 columns]

# %%
pop.describe()
# Out:
#               year    population
# count  2544.000000  2.524000e+03
# mean   2001.500000  6.805558e+06
# std       6.923547  2.855014e+07
# min    1990.000000  1.013090e+05
# 25%    1995.750000  7.423805e+05
# 50%    2001.500000  1.597005e+06
# 75%    2007.250000  4.547104e+06
# max    2013.000000  3.161288e+08

# %% [markdown]
# ## GroupBy: 분할, 적용, 결합

# %% [markdown]
# 각 열에 대한 여러 일반적인 집계를 계산하고 결과를 반환하는 describe() 메서드가 있다. 간단한 집계는 데이터세트의 전반적인 특성을 알려주지만, 때에 따라서는 어떤 행이나 인덱스를 기준으로 조건부로 집계할 경우가 있다. 이때 GroupBy 연산을 활용한다.

# %% [markdown]
# #### 분할, 적용, 결합

# %% [markdown]
# - 분할 : 지정된 키값을 기준으로 데이터프레임을 나누고 분류
# - 적용 : 개별 그룹 내에서 일반적으로 집계, 변환, 필터링 같은 함수를 계산
# - 결합 : 연산의 결과를 결과 배열에 병합

# %%
df = pd.DataFrame({'key' : ['A','B','C','A','B','C'],
                  'data' : range(6)},
                 columns = ['key','data'])

# %%
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %% [markdown]
# ##### Tip) 컬럼 순서 바꾸기

# %%
pop.head()
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
#데이터프레임[컬럼리스트]
pop = pop[['population','year','ages','state/region']]

# %%
pop.head()
# Out:
#    population  year     ages state/region
# 0   1117489.0  2012  under18           AL
# 1   4817528.0  2012    total           AL
# 2   1130966.0  2010  under18           AL
# 3   4785570.0  2010    total           AL
# 4   1125763.0  2011  under18           AL

# %% [markdown]
# 데이터프레임의 groupby()메서드에 원하는 키 열의 이름을 전달해 가장 기본적인 분할, 적용, 결합 연결을 계산

# %%
df.groupby('key')

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %% [markdown]
# ### 집계, 필터, 변환, 적용

# %% [markdown]
# sum(), median() 등을 활용하여 데이터프레임의 데이터를 집계하였지만 aggregate() 메서드를 활용하면 더 유연하게 집계 할 수 있다.

# %%
rng = np.random.RandomState(0)
df = pd.DataFrame({'key' : ['A','B','C','A','B','C'],
                  'data1' : range(6),
                  'data2' : rng.randint(0,10,6)},
                 columns = ['key','data1','data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key').aggregate([min, max, np.median])
# Out:
#     data1            data2
#       min max median   min max median
# key
# A       0   3    1.5     3   5    4.0
# B       1   4    2.5     0   7    3.5
# C       2   5    3.5     3   9    6.0

# %% [markdown]
# 열 이름을 해당 열에 적용될 연산에 매핑하는 딕셔너리를 전달하여 같은 동작을 수행할 수 있다.

# %%
df.groupby('key').aggregate({'data1':'min', 'data2':'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# ### 필터링

# %% [markdown]
# 필터링 연산을 사용하면 그룹 속성을 기준으로 데이터를 걸러낼 수 있다.

# %%
def filter_func(x):
    return x['data2'].std() > 4

# %%
df.groupby('key').std()
# Out:
#        data1     data2
# key
# A    2.12132  1.414214
# B    2.12132  4.949747
# C    2.12132  4.242641

# %%
df.groupby('key').filter(filter_func)
# Out:
#   key  data1  data2
# 1   B      1      0
# 2   C      2      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# #### 변환

# %% [markdown]
# 데이터의 내용을 재 계산하여 데이터가 바뀐 버전의 새로운 데이터프레임을 만들 수 있다.

# %%
df.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %%
df.groupby('key').mean()
# Out:
#      data1  data2
# key
# A      1.5    4.0
# B      2.5    3.5
# C      3.5    6.0

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %% [markdown]
# 함수를 활용하고 싶다면 apply() 메서드를 활용한다.

# %%
def norm_by_data2(x):
    x['data13'] = x['data2'].sum()
    return x

# %%
df.groupby('key').apply(norm_by_data2)
# Out:
#   key  data1  data2  data13
# 0   A      0      5       8
# 1   B      1      0       7
# 2   C      2      3      12
# 3   A      3      3       8
# 4   B      4      7       7
# 5   C      5      9      12

# %% [markdown]
# ##### quiz)
# 위의 예제에서 groupby를 활용하여 key를 기준으로한 data2의 평균을 표시하세요.

# %%
def norm_by_data2(x):
    x['평균'] = x['data2'].mean()
    return x

# %%
df.groupby('key').apply(norm_by_data2)
# Out:
#   key  data1  data2   평균
# 0   A      0      5  4.0
# 1   B      1      0  3.5
# 2   C      2      3  6.0
# 3   A      3      3  4.0
# 4   B      4      7  3.5
# 5   C      5      9  6.0

# %% [markdown]
# ### 분할 키 지정하기(그룹 지정)

# %% [markdown]
# 하나의 열 이름을 기준으로 DataFrame을 분할 하였지만 리스트, 딕셔너리, 리스트를 활용하여 그룹을 만들수 있다.

# %%
L = [0,1,0,1,2,0]
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby(L).sum()# L = [0,1,0,1,2,0]
# Out:
#    data1  data2
# 0      7     17
# 1      4      3
# 2      4      7

# %% [markdown]
# ### 딕셔너리

# %%
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df2 = df.set_index('key')
df2
# Out:
#      data1  data2
# key
# A        0      5
# B        1      0
# C        2      3
# A        3      3
# B        4      7
# C        5      9

# %%
mapping = {'A':'Banana','B':'Apple','C':'Apple'}

# %%
df2.groupby(mapping).sum()
# Out:
#         data1  data2
# Apple      12     19
# Banana      3      8

# %% [markdown]
# #### 인덱스

# %% [markdown]
# 인덱스의 그룹을 출력하는 파이썬함수를 활용할 수 있다.

# %%
df2.index
# Out:
# Index(['A', 'B', 'C', 'A', 'B', 'C'], dtype='object', name='key')

# %%
df2.groupby(df2.index).mean()
# Out:
#      data1  data2
# key
# A      1.5    4.0
# B      2.5    3.5
# C      3.5    6.0

# %% [markdown]
# 앞에서 다룬 방식을 리스트로 다중인덱스로 구성할 수 있다.

# %%
df2.groupby([df2.index, mapping]).mean()
# Out:
#             data1  data2
# key
# A   Banana    1.5    4.0
# B   Apple     2.5    3.5
# C   Apple     3.5    6.0

# %% [markdown]
# #### 예시

# %%
import seaborn as sns
planets = sns.load_dataset('planets')

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
decade = (planets['year'] // 10) * 10
decade = decade.astype(str)+'s'
decade.head()
# Out:
# 0    2000s
# 1    2000s
# 2    2010s
# 3    2000s
# 4    2000s
# Name: year, dtype: object

# %%
planets.groupby(['method', decade])['number'].sum().unstack().fillna(0)
# Out:
# year                           1980s  1990s  2000s  2010s
# method
# Astrometry                       0.0    0.0    0.0    2.0
# Eclipse Timing Variations        0.0    0.0    5.0   10.0
# Imaging                          0.0    0.0   29.0   21.0
# Microlensing                     0.0    0.0   12.0   15.0
# Orbital Brightness Modulation    0.0    0.0    0.0    5.0
# Pulsar Timing                    0.0    9.0    1.0    1.0
# Pulsation Timing Variations      0.0    0.0    1.0    0.0
# Radial Velocity                  1.0   52.0  475.0  424.0
# Transit                          0.0    0.0   64.0  712.0
# Transit Timing Variations        0.0    0.0    0.0    9.0
